# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # Read data from the URL for test / train sentences.
#
# # Constructs proper sentences from individual words and prints five sentences
#
# # Correctly counts the number of sentences in the processed train and test dataset
# # Correctly counts the number of lines of labels in the processed train and test datasets

# %%
## Read data from the url
def read_data_from_url(url):
  response = requests.get(url)
  data = response.text

  return data

# %%
### Read data from the train sentences url
train_sentences_url = "https://raw.githubusercontent.com/TheExorcist/NER-datasets/main/train_sent"
train_sentences_data = read_data_from_url(train_sentences_url)

# %%
def generate_sentences(data):
  sentences = []
  sentence = ""
  for line in data.split('\n'):
    line = line.strip()
    if line == "":
      sentences.append(sentence.strip())
      sentence = ""
    else:
      sentence += line + " "
  return sentences

# %%
# Out:
# ['All', 'live', 'births', '>', 'or', '=', '23', 'weeks', 'at', 'the', 'University', 'of', 'Vermont', 'in', '1995', '(', 'n', '=', '2395', ')', 'were', 'retrospectively', 'analyzed', 'for', 'delivery', 'route', ',', 'indication', 'for', 'cesarean', ',', 'gestational', 'age', ',', 'parity', ',', 'and', 'practice', 'group', '(', 'to', 'reflect', 'risk', 'status', ')', '.']

# %%
## convert sentence tokens to the sentences using spacy
train_sentences = generate_sentences(train_sentences_data)
train_sentences[0:5]
# Out:
# ['All live births > or = 23 weeks at the University of Vermont in 1995 ( n = 2395 ) were retrospectively analyzed for delivery route , indication for cesarean , gestational age , parity , and practice group ( to reflect risk status )',
#  'The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )',
#  'Abnormal presentation was the most common indication ( 25.6 % , 88 of 344 )',
#  "The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )",
#  "Arrest of dilation was the most common indication in both `` corrected '' subgroups ( 23.4 and 24.6 % , respectively )"]

# %%
## length of the sentences
print(len(train_sentences))
# Out:
# 2600

# %%
# count the number of lines in the train labels.
train_label_url = "https://raw.githubusercontent.com/TheExorcist/NER-datasets/main/train_label"
train_label_data = read_data_from_url(train_label_url)
train_label_sentences = generate_sentences(train_label_data)

# %%
# count the number of train labels.
len(train_label_sentences)
# Out:
# 2600

# %%
## Read data from the test sentences
test_sentences_url = "https://raw.githubusercontent.com/TheExorcist/NER-datasets/main/test_sent"
test_sentences_data = read_data_from_url(test_sentences_url)
test_sentences = generate_sentences(test_sentences_data)

# %%
## print length of the test sentence
print(len(test_sentences))
# Out:
# 1057

# %% [markdown]
# # Writes the code to get a list of labels of a given preprocessed label line that you have created earlie

# %%
## Read data from the test label
test_label_url = "https://raw.githubusercontent.com/TheExorcist/NER-datasets/main/test_label"
test_label_data = read_data_from_url(test_label_url)
test_label_sentences = generate_sentences(test_label_data)

# %%
## print length of the test labels
print(len(test_label_sentences))
# Out:
# 1057

# %% [markdown]
# # Uses a toolkit like spaCy to extract those tokens that have NOUN or PROPN as their PoS tag and finds their frequency from the entire dataset that comprises both the train and the test datasets

# %%
from collections import Counter

def count_pos_tags(sentences):
  pos_tag = ['NOUN', 'PROPN']
  counter = Counter()
  for sentence in sentences:
    doc = nlp(sentence)
    for token in doc:
      if token.pos_ in pos_tag:
        counter[token.text] += 1
  return counter

# %%
all_sentences = train_sentences + test_sentences
token_counter = count_pos_tags(all_sentences)

# %% [markdown]
# # Prints the top 25 most common tokens with NOUN or PROPN PoS tags for the entire dataset that comprises both the train and the test datasets

# %%
token_counter.most_common(25)
# Out:
# [('patients', 492),
#  ('treatment', 281),
#  ('%', 247),
#  ('cancer', 200),
#  ('therapy', 175),
#  ('study', 154),
#  ('disease', 142),
#  ('cell', 140),
#  ('lung', 116),
#  ('group', 94),
#  ('gene', 88),
#  ('chemotherapy', 88),
#  ('effects', 85),
#  ('results', 79),
#  ('women', 77),
#  ('use', 74),
#  ('TO_SEE', 74),
#  ('risk', 71),
#  ('cases', 71),
#  ('surgery', 71),
#  ('analysis', 70),
#  ('rate', 67),
#  ('response', 66),
#  ('survival', 65),
#  ('children', 64)]

# %%
## print label lines
train_labels = list(map(lambda x: x.strip(), train_label_sentences))
train_labels = list(map(lambda x: x.split(), train_labels))
train_labels[0:5]
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %% [markdown]
# # Extracts the features' values for each sentence as an input variable for the CRF model in the test and the train datasets

# %%
def extract_features(doc, index):
    """
    Extract features for a token at a given index in the document, including sentence boundary markers.

    Args:
    - doc (spacy.tokens.Doc): A spaCy Doc object containing the processed text.
    - index (int): The index of the token for which to extract features.

    Returns:
    - dict: A dictionary of features for the token at the specified index.
    """
    token = doc[index]

    # Basic features of the current token
    features = {
        'text': token.text,                    # Current token text
        'lowercase': token.text.lower(),       # Lowercase version of the token
        'pos': token.pos_,                     # Coarse-grained POS tag of the current token
        'tag': token.tag_,                     # Fine-grained POS tag of the current token
        'shape': token.shape_,                 # Shape of the current token (e.g., 'Xxxxx', 'd' for digits)
        'is_alpha': token.is_alpha,            # Whether the token is alphabetic
        'is_title': token.is_title,            # Whether the token is title-cased
        'is_digit': token.is_digit,            # Whether the token is a digit
        'is_stop': token.is_stop               # Whether the token is a stop word
    }

    # Features from the previous token, if it exists
    if index > 0:
        prev_token = doc[index - 1]
        features.update({
            'prev_text': prev_token.text,      # Previous token text
            'prev_lowercase': prev_token.text.lower(),  # Lowercase of the previous token
            'prev_pos': prev_token.pos_,       # Coarse-grained POS tag of the previous token
            'prev_tag': prev_token.tag_,       # Fine-grained POS tag of the previous token
            'prev_shape': prev_token.shape_,   # Shape of the previous token
            'prev_is_alpha': prev_token.is_alpha,  # Whether the previous token is alphabetic
            'prev_is_title': prev_token.is_title,  # Whether the previous token is title-cased
            'prev_is_digit': prev_token.is_digit,  # Whether the previous token is a digit
            'prev_is_stop': prev_token.is_stop  # Whether the previous token is a stop word
        })
    else:
        # Special features for the first token where there is no previous token
        features.update({
            'prev_text': '<START>',
            'prev_pos': '<START>',
            'prev_tag': '<START>',
            'prev_shape': '<START>',
            'prev_is_alpha': False,
            'prev_is_title': False,
            'prev_is_digit': False,
            'prev_is_stop': False
        })

    # Sentence boundary features
    features.update({
        'is_sentence_start': token.is_sent_start,  # Whether the token is at the start of a sentence
        'is_sentence_end': token.is_sent_end       # Whether the token is at the end of a sentence
    })

    return features


train_features = []
for index, sentence in enumerate(train_sentences):
    doc = nlp(sentence)
    train_feature_list = []
    for i in range(len(doc)):
      train_feature_list.append(extract_features(doc, i))
    train_features.append(train_feature_list[0: len(train_labels[index])])

# %%
print(train_features[0:30])
# Out:
# [[{'text': 'All', 'lowercase': 'all', 'pos': 'DET', 'tag': 'DT', 'shape': 'Xxx', 'is_alpha': True, 'is_title': True, 'is_digit': False, 'is_stop': True, 'prev_text': '<START>', 'prev_pos': '<START>', 'prev_tag': '<START>', 'prev_shape': '<START>', 'prev_is_alpha': False, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': True, 'is_sentence_end': False}, {'text': 'live', 'lowercase': 'live', 'pos': 'ADJ', 'tag': 'JJ', 'shape': 'xxxx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': False, 'prev_text': 'All', 'prev_lowercase': 'all', 'prev_pos': 'DET', 'prev_tag': 'DT', 'prev_shape': 'Xxx', 'prev_is_alpha': True, 'prev_is_title': True, 'prev_is_digit': False, 'prev_is_stop': True, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': 'births', 'lowercase': 'births', 'pos': 'NOUN', 'tag': 'NNS', 'shape': 'xxxx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': False, 'prev_text': 'live', 'prev_lowercase': 'live', 'prev_pos': 'ADJ', 'prev_tag': 'JJ', 'prev_shape': 'xxxx', 'prev_is_alpha': True, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': '>', 'lowercase': '>', 'pos': 'X', 'tag': 'ADD', 'shape': '>', 'is_alpha': False, 'is_title': False, 'is_digit': False, 'is_stop': False, 'prev_text': 'births', 'prev_lowercase': 'births', 'prev_pos': 'NOUN', 'prev_tag': 'NNS', 'prev_shape': 'xxxx', 'prev_is_alpha': True, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': 'or', 'lowercase': 'or', 'pos': 'CCONJ', 'tag': 'CC', 'shape': 'xx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': True, 'prev_text': '>', 'prev_lowercase': '>', 'prev_pos': 'X', 'prev_tag': 'ADD', 'prev_shape': '>', 'prev_is_alpha': False, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': '=', 'lowercase': '=', 'pos': 'PRON', 'tag': 'PRP', 'shape': '=', 'is_alpha': False, 'is_title': False, 'is_digit': False, 'is_stop': False, 'prev_text': 'or', 'prev_lowercase': 'or', 'prev_pos': 'CCONJ', 'prev_tag': 'CC', 'prev_shape': 'xx', 'prev_is_alpha': True, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': True, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': '23', 'lowercase': '23', 'pos': 'NUM', 'tag': 'CD', 'shape': 'dd', 'is_alpha': False, 'is_title': False, 'is_digit': True, 'is_stop': False, 'prev_text': '=', 'prev_lowercase': '=', 'prev_pos': 'PRON', 'prev_tag': 'PRP', 'prev_shape': '=', 'prev_is_alpha': False, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': 'weeks', 'lowercase': 'weeks', 'pos': 'NOUN', 'tag': 'NNS', 'shape': 'xxxx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': False, 'prev_text': '23', 'prev_lowercase': '23', 'prev_pos': 'NUM', 'prev_tag': 'CD', 'prev_shape': 'dd', 'prev_is_alpha': False, 'prev_is_title': False, 'prev_is_digit': True, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': 'at', 'lowercase': 'at', 'pos': 'ADP', 'tag': 'IN', 'shape': 'xx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': True, 'prev_text': 'weeks', 'prev_lowercase': 'weeks', 'prev_pos': 'NOUN', 'prev_tag': 'NNS', 'prev_shape': 'xxxx', 'prev_is_alpha': True, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': False, 'is_sentence_start': False, 'is_sentence_end': False}, {'text': 'the', 'lowercase': 'the', 'pos': 'DET', 'tag': 'DT', 'shape': 'xxx', 'is_alpha': True, 'is_title': False, 'is_digit': False, 'is_stop': True, 'prev_text': 'at', 'prev_lowercase': 'at', 'prev_pos': 'ADP', 'prev_tag': 'IN', 'prev_shape': 'xx', 'prev_is_alpha': True, 'prev_is_title': False, 'prev_is_digit': False, 'prev_is_stop': True, 'is_sentence_s ...

# %%
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
print(len(train_features))
print(len(train_labels))
# Out:
# 2600
# 2600

# %%
## features for the test sentenances
test_features = []
for sentence in test_sentences:
    doc = nlp(sentence)
    feature_list = []
    for i in range(len(doc)):
        feature_list.append(extract_features(doc, i))

    test_features.append(feature_list)

test_features[0:5]
# Out:
# [[{'text': 'Furthermore',
#    'lowercase': 'furthermore',
#    'pos': 'ADV',
#    'tag': 'RB',
#    'shape': 'Xxxxx',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '<START>',
#    'prev_pos': '<START>',
#    'prev_tag': '<START>',
#    'prev_shape': '<START>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': True,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'Furthermore',
#    'prev_lowercase': 'furthermore',
#    'prev_pos': 'ADV',
#    'prev_tag': 'RB',
#    'prev_shape': 'Xxxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'when',
#    'lowercase': 'when',
#    'pos': 'SCONJ',
#    'tag': 'WRB',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'all',
#    'lowercase': 'all',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'when',
#    'prev_lowercase': 'when',
#    'prev_pos': 'SCONJ',
#    'prev_tag': 'WRB',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'deliveries',
#    'lowercase': 'deliveries',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'all',
#    'prev_lowercase': 'all',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'were',
#    'lowercase': 'were',
#    'pos': 'AUX',
#    'tag': 'VBD',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'deliveries',
#    'prev_lowercase': 'deliveries',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'analyzed',
#    'lowercase': 'analyzed',
#    'pos': 'VERB',
#    'tag': 'VBN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'were',
#    'prev_lowercase': 'were',
#    'prev_pos': 'AUX',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'analyzed',
#    'prev_lowercase': 'analyzed',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'regardless',
#    'lowercase': 'regardless',
#    'pos': 'ADV',
#    'tag': 'RB',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'of',
#    'lowercase': 'of',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'regardless',
#    'prev_lowercase': 'regardless',
#    'prev_pos': 'ADV',
#    'prev_tag': 'RB',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'risk',
#    'lowercase': 'risk',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'of',
#    'prev_lowercase': 'of',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'status',
#    'lowercase': 'status',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'risk',
#    'prev_lowercase': 'risk',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'but',
#    'lowercase': 'but',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'status',
#    'prev_lowercase': 'status',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'limited',
#    'lowercase': 'limited',
#    'pos': 'VERB',
#    'tag': 'VBD',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'but',
#    'prev_lowercase': 'but',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'to',
#    'lowercase': 'to',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'limited',
#    'prev_lowercase': 'limited',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'gestational',
#    'lowercase': 'gestational',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'to',
#    'prev_lowercase': 'to',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'age',
#    'lowercase': 'age',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'gestational',
#    'prev_lowercase': 'gestational',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '>',
#    'lowercase': '>',
#    'pos': 'PUNCT',
#    'tag': '-RRB-',
#    'shape': '>',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'age',
#    'prev_lowercase': 'age',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'or',
#    'lowercase': 'or',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '>',
#    'prev_lowercase': '>',
#    'prev_pos': 'PUNCT',
#    'prev_tag': '-RRB-',
#    'prev_shape': '>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '=',
#    'lowercase': '=',
#    'pos': 'PRON',
#    'tag': 'PRP',
#    'shape': '=',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'or',
#    'prev_lowercase': 'or',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '36',
#    'lowercase': '36',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': '=',
#    'prev_lowercase': '=',
#    'prev_pos': 'PRON',
#    'prev_tag': 'PRP',
#    'prev_shape': '=',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'weeks',
#    'lowercase': 'weeks',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '36',
#    'prev_lowercase': '36',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'weeks',
#    'prev_lowercase': 'weeks',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'rates',
#    'lowercase': 'rates',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'did',
#    'lowercase': 'did',
#    'pos': 'AUX',
#    'tag': 'VBD',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'rates',
#    'prev_lowercase': 'rates',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'not',
#    'lowercase': 'not',
#    'pos': 'PART',
#    'tag': 'RB',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'did',
#    'prev_lowercase': 'did',
#    'prev_pos': 'AUX',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'change',
#    'lowercase': 'change',
#    'pos': 'VERB',
#    'tag': 'VB',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'not',
#    'prev_lowercase': 'not',
#    'prev_pos': 'PART',
#    'prev_tag': 'RB',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '(',
#    'lowercase': '(',
#    'pos': 'PUNCT',
#    'tag': '-LRB-',
#    'shape': '(',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'change',
#    'prev_lowercase': 'change',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VB',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '12.6',
#    'lowercase': '12.6',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dd.d',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '(',
#    'prev_lowercase': '(',
#    'prev_pos': 'PUNCT',
#    'prev_tag': '-LRB-',
#    'prev_shape': '(',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '%',
#    'lowercase': '%',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': '%',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '12.6',
#    'prev_lowercase': '12.6',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dd.d',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '%',
#    'prev_lowercase': '%',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': '%',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '280',
#    'lowercase': '280',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'ddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'of',
#    'lowercase': 'of',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '280',
#    'prev_lowercase': '280',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'ddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '2214',
#    'lowercase': '2214',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'of',
#    'prev_lowercase': 'of',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ';',
#    'lowercase': ';',
#    'pos': 'PUNCT',
#    'tag': ':',
#    'shape': ';',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '2214',
#    'prev_lowercase': '2214',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'primary',
#    'lowercase': 'primary',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': ';',
#    'prev_lowercase': ';',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ':',
#    'prev_shape': ';',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '9.2',
#    'lowercase': '9.2',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd.d',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'primary',
#    'prev_lowercase': 'primary',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '%',
#    'lowercase': '%',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': '%',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '9.2',
#    'prev_lowercase': '9.2',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd.d',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '%',
#    'prev_lowercase': '%',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': '%',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '183',
#    'lowercase': '183',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'ddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'of',
#    'lowercase': 'of',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '183',
#    'prev_lowercase': '183',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'ddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '1994',
#    'lowercase': '1994',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'of',
#    'prev_lowercase': 'of',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ')',
#    'lowercase': ')',
#    'pos': 'PUNCT',
#    'tag': '-RRB-',
#    'shape': ')',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '1994',
#    'prev_lowercase': '1994',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': True}],
#  [{'text': 'As',
#    'lowercase': 'as',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'Xx',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '<START>',
#    'prev_pos': '<START>',
#    'prev_tag': '<START>',
#    'prev_shape': '<START>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': True,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'As',
#    'prev_lowercase': 'as',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'Xx',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'ambient',
#    'lowercase': 'ambient',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'temperature',
#    'lowercase': 'temperature',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'ambient',
#    'prev_lowercase': 'ambient',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'increases',
#    'lowercase': 'increases',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'temperature',
#    'prev_lowercase': 'temperature',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'increases',
#    'prev_lowercase': 'increases',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'there',
#    'lowercase': 'there',
#    'pos': 'PRON',
#    'tag': 'EX',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'is',
#    'lowercase': 'is',
#    'pos': 'VERB',
#    'tag': 'VBZ',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'there',
#    'prev_lowercase': 'there',
#    'prev_pos': 'PRON',
#    'prev_tag': 'EX',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'an',
#    'lowercase': 'an',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'is',
#    'prev_lowercase': 'is',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBZ',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'increase',
#    'lowercase': 'increase',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'an',
#    'prev_lowercase': 'an',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'in',
#    'lowercase': 'in',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'increase',
#    'prev_lowercase': 'increase',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'insensible',
#    'lowercase': 'insensible',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'in',
#    'prev_lowercase': 'in',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'fluid',
#    'lowercase': 'fluid',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'insensible',
#    'prev_lowercase': 'insensible',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'loss',
#    'lowercase': 'loss',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'fluid',
#    'prev_lowercase': 'fluid',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'and',
#    'lowercase': 'and',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'loss',
#    'prev_lowercase': 'loss',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'and',
#    'prev_lowercase': 'and',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'potential',
#    'lowercase': 'potential',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'for',
#    'lowercase': 'for',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'potential',
#    'prev_lowercase': 'potential',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'dehydration',
#    'lowercase': 'dehydration',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'for',
#    'prev_lowercase': 'for',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': True}],
#  [{'text': 'The',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'Xxx',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '<START>',
#    'prev_pos': '<START>',
#    'prev_tag': '<START>',
#    'prev_shape': '<START>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': True,
#    'is_sentence_end': False},
#   {'text': 'daily',
#    'lowercase': 'daily',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'The',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'Xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'high',
#    'lowercase': 'high',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'daily',
#    'prev_lowercase': 'daily',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'temperature',
#    'lowercase': 'temperature',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'high',
#    'prev_lowercase': 'high',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'ranged',
#    'lowercase': 'ranged',
#    'pos': 'VERB',
#    'tag': 'VBD',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'temperature',
#    'prev_lowercase': 'temperature',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'from',
#    'lowercase': 'from',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'ranged',
#    'prev_lowercase': 'ranged',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '71',
#    'lowercase': '71',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'from',
#    'prev_lowercase': 'from',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'to',
#    'lowercase': 'to',
#    'pos': 'PART',
#    'tag': 'TO',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '71',
#    'prev_lowercase': '71',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '104',
#    'lowercase': '104',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'ddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'to',
#    'prev_lowercase': 'to',
#    'prev_pos': 'PART',
#    'prev_tag': 'TO',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'degrees',
#    'lowercase': 'degrees',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '104',
#    'prev_lowercase': '104',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'ddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'F',
#    'lowercase': 'f',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': 'X',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'degrees',
#    'prev_lowercase': 'degrees',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'and',
#    'lowercase': 'and',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'F',
#    'prev_lowercase': 'f',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': 'X',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'AFI',
#    'lowercase': 'afi',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': 'XXX',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'and',
#    'prev_lowercase': 'and',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'values',
#    'lowercase': 'values',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'AFI',
#    'prev_lowercase': 'afi',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': 'XXX',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'ranged',
#    'lowercase': 'ranged',
#    'pos': 'VERB',
#    'tag': 'VBD',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'values',
#    'prev_lowercase': 'values',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'from',
#    'lowercase': 'from',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'ranged',
#    'prev_lowercase': 'ranged',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '1.7',
#    'lowercase': '1.7',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd.d',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'from',
#    'prev_lowercase': 'from',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'to',
#    'lowercase': 'to',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '1.7',
#    'prev_lowercase': '1.7',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd.d',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '24.7',
#    'lowercase': '24.7',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dd.d',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'to',
#    'prev_lowercase': 'to',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'cm',
#    'lowercase': 'cm',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '24.7',
#    'prev_lowercase': '24.7',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dd.d',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'during',
#    'lowercase': 'during',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'cm',
#    'prev_lowercase': 'cm',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'during',
#    'prev_lowercase': 'during',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'study',
#    'lowercase': 'study',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'period',
#    'lowercase': 'period',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'study',
#    'prev_lowercase': 'study',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': True}],
#  [{'text': 'There',
#    'lowercase': 'there',
#    'pos': 'PRON',
#    'tag': 'EX',
#    'shape': 'Xxxxx',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': '<START>',
#    'prev_pos': '<START>',
#    'prev_tag': '<START>',
#    'prev_shape': '<START>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': True,
#    'is_sentence_end': False},
#   {'text': 'was',
#    'lowercase': 'was',
#    'pos': 'VERB',
#    'tag': 'VBD',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'There',
#    'prev_lowercase': 'there',
#    'prev_pos': 'PRON',
#    'prev_tag': 'EX',
#    'prev_shape': 'Xxxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'a',
#    'lowercase': 'a',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'x',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'was',
#    'prev_lowercase': 'was',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBD',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'significant',
#    'lowercase': 'significant',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'a',
#    'prev_lowercase': 'a',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'x',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'correlation',
#    'lowercase': 'correlation',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'significant',
#    'prev_lowercase': 'significant',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'between',
#    'lowercase': 'between',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'correlation',
#    'prev_lowercase': 'correlation',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'between',
#    'prev_lowercase': 'between',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '2-',
#    'lowercase': '2-',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': 'd-',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '2-',
#    'prev_lowercase': '2-',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': 'd-',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '3-',
#    'lowercase': '3-',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd-',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '3-',
#    'prev_lowercase': '3-',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd-',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'and',
#    'lowercase': 'and',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '4',
#    'lowercase': '4',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'and',
#    'prev_lowercase': 'and',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '-',
#    'lowercase': '-',
#    'pos': 'PUNCT',
#    'tag': 'HYPH',
#    'shape': '-',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '4',
#    'prev_lowercase': '4',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'day',
#    'lowercase': 'day',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '-',
#    'prev_lowercase': '-',
#    'prev_pos': 'PUNCT',
#    'prev_tag': 'HYPH',
#    'prev_shape': '-',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'mean',
#    'lowercase': 'mean',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
# ...
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'AFI',
#    'prev_lowercase': 'afi',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': 'XXX',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'with',
#    'lowercase': 'with',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'with',
#    'prev_lowercase': 'with',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '4',
#    'lowercase': '4',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '-',
#    'lowercase': '-',
#    'pos': 'PUNCT',
#    'tag': 'HYPH',
#    'shape': '-',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '4',
#    'prev_lowercase': '4',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'day',
#    'lowercase': 'day',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '-',
#    'prev_lowercase': '-',
#    'prev_pos': 'PUNCT',
#    'prev_tag': 'HYPH',
#    'prev_shape': '-',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'mean',
#    'lowercase': 'mean',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'day',
#    'prev_lowercase': 'day',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'being',
#    'lowercase': 'being',
#    'pos': 'AUX',
#    'tag': 'VBG',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'mean',
#    'prev_lowercase': 'mean',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'the',
#    'lowercase': 'the',
#    'pos': 'DET',
#    'tag': 'DT',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'being',
#    'prev_lowercase': 'being',
#    'prev_pos': 'AUX',
#    'prev_tag': 'VBG',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'most',
#    'lowercase': 'most',
#    'pos': 'ADV',
#    'tag': 'RBS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'the',
#    'prev_lowercase': 'the',
#    'prev_pos': 'DET',
#    'prev_tag': 'DT',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'significant',
#    'lowercase': 'significant',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'most',
#    'prev_lowercase': 'most',
#    'prev_pos': 'ADV',
#    'prev_tag': 'RBS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '(',
#    'lowercase': '(',
#    'pos': 'PUNCT',
#    'tag': '-LRB-',
#    'shape': '(',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'significant',
#    'prev_lowercase': 'significant',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'r',
#    'lowercase': 'r',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'x',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '(',
#    'prev_lowercase': '(',
#    'prev_pos': 'PUNCT',
#    'prev_tag': '-LRB-',
#    'prev_shape': '(',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '=',
#    'lowercase': '=',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': '=',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'r',
#    'prev_lowercase': 'r',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'x',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '0.31',
#    'lowercase': '0.31',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd.dd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '=',
#    'prev_lowercase': '=',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': '=',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ',',
#    'lowercase': ',',
#    'pos': 'PUNCT',
#    'tag': ',',
#    'shape': ',',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '0.31',
#    'prev_lowercase': '0.31',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd.dd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'p',
#    'lowercase': 'p',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': 'x',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': ',',
#    'prev_lowercase': ',',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ',',
#    'prev_shape': ',',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '&',
#    'lowercase': '&',
#    'pos': 'CCONJ',
#    'tag': 'CC',
#    'shape': '&',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'p',
#    'prev_lowercase': 'p',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': 'x',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '#',
#    'lowercase': '#',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': '#',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '&',
#    'prev_lowercase': '&',
#    'prev_pos': 'CCONJ',
#    'prev_tag': 'CC',
#    'prev_shape': '&',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '60',
#    'lowercase': '60',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'dd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': True,
#    'is_stop': False,
#    'prev_text': '#',
#    'prev_lowercase': '#',
#    'prev_pos': 'PROPN',
#    'prev_tag': 'NNP',
#    'prev_shape': '#',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ';',
#    'lowercase': ';',
#    'pos': 'PUNCT',
#    'tag': ':',
#    'shape': ';',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '60',
#    'prev_lowercase': '60',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'dd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': True,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': '0.001',
#    'lowercase': '0.001',
#    'pos': 'NUM',
#    'tag': 'CD',
#    'shape': 'd.ddd',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': ';',
#    'prev_lowercase': ';',
#    'prev_pos': 'PUNCT',
#    'prev_tag': ':',
#    'prev_shape': ';',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': ')',
#    'lowercase': ')',
#    'pos': 'PUNCT',
#    'tag': '-RRB-',
#    'shape': ')',
#    'is_alpha': False,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '0.001',
#    'prev_lowercase': '0.001',
#    'prev_pos': 'NUM',
#    'prev_tag': 'CD',
#    'prev_shape': 'd.ddd',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': True}],
#  [{'text': 'Fluctuations',
#    'lowercase': 'fluctuations',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'Xxxxx',
#    'is_alpha': True,
#    'is_title': True,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': '<START>',
#    'prev_pos': '<START>',
#    'prev_tag': '<START>',
#    'prev_shape': '<START>',
#    'prev_is_alpha': False,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': True,
#    'is_sentence_end': False},
#   {'text': 'in',
#    'lowercase': 'in',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'Fluctuations',
#    'prev_lowercase': 'fluctuations',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'Xxxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': True,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'ambient',
#    'lowercase': 'ambient',
#    'pos': 'ADJ',
#    'tag': 'JJ',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'in',
#    'prev_lowercase': 'in',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'temperature',
#    'lowercase': 'temperature',
#    'pos': 'NOUN',
#    'tag': 'NN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'ambient',
#    'prev_lowercase': 'ambient',
#    'prev_pos': 'ADJ',
#    'prev_tag': 'JJ',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'are',
#    'lowercase': 'are',
#    'pos': 'AUX',
#    'tag': 'VBP',
#    'shape': 'xxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'temperature',
#    'prev_lowercase': 'temperature',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'inversely',
#    'lowercase': 'inversely',
#    'pos': 'ADV',
#    'tag': 'RB',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'are',
#    'prev_lowercase': 'are',
#    'prev_pos': 'AUX',
#    'prev_tag': 'VBP',
#    'prev_shape': 'xxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'correlated',
#    'lowercase': 'correlated',
#    'pos': 'VERB',
#    'tag': 'VBN',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'inversely',
#    'prev_lowercase': 'inversely',
#    'prev_pos': 'ADV',
#    'prev_tag': 'RB',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'to',
#    'lowercase': 'to',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'correlated',
#    'prev_lowercase': 'correlated',
#    'prev_pos': 'VERB',
#    'prev_tag': 'VBN',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'changes',
#    'lowercase': 'changes',
#    'pos': 'NOUN',
#    'tag': 'NNS',
#    'shape': 'xxxx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'to',
#    'prev_lowercase': 'to',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'in',
#    'lowercase': 'in',
#    'pos': 'ADP',
#    'tag': 'IN',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': True,
#    'prev_text': 'changes',
#    'prev_lowercase': 'changes',
#    'prev_pos': 'NOUN',
#    'prev_tag': 'NNS',
#    'prev_shape': 'xxxx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': False,
#    'is_sentence_start': False,
#    'is_sentence_end': False},
#   {'text': 'AFI',
#    'lowercase': 'afi',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'shape': 'XXX',
#    'is_alpha': True,
#    'is_title': False,
#    'is_digit': False,
#    'is_stop': False,
#    'prev_text': 'in',
#    'prev_lowercase': 'in',
#    'prev_pos': 'ADP',
#    'prev_tag': 'IN',
#    'prev_shape': 'xx',
#    'prev_is_alpha': True,
#    'prev_is_title': False,
#    'prev_is_digit': False,
#    'prev_is_stop': True,
#    'is_sentence_start': False,
#    'is_sentence_end': True}]]

# %%
## get the train feature length

print(len(test_features))
print(len(test_labels))
# Out:
# 1057
# 1057

# %% [markdown]
# # Extracts the labels as the target variable for the test and the train datasets

# %%
test_labels = list(map(lambda x: x.strip(), test_label_sentences))
test_labels = list(map(lambda x: x.split(), test_labels))
test_labels[0:5]
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]

# %%
# !pip install sklearn-crfsuite
# Out:
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: python-crfsuite>=0.9.7 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite) (0.9.10)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite) (1.3.2)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite) (4.66.5)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (3.5.0)

# %%
def validating_dimensions_for_training_dataset(training_features, training_labels):
  mismatch_count = 0

  for training_feature, training_label in zip(training_features, training_labels):
    if len(training_feature) != len(training_label):
      # print(training_feature, training_label)
      # print(len(training_feature), len(training_label))
      mismatch_count += 1
  print(mismatch_count)
  return True

# %%
validating_dimensions_for_training_dataset(train_features, train_labels)
# Out:
# 2599
# True

# %% [markdown]
# # Predicts the labels of each of the tokens in each sentence of the test dataset that has been preprocessed earlier
#
# Builds the CRF model for a custom NER application

# %%
## using sklearn_crfsuite to Build the CRF model for a custom NER application
import sklearn_crfsuite

crf = sklearn_crfsuite.CRF(max_iterations=100)
crf.fit(train_features, train_labels)
test_predictions = crf.predict(test_features)
test_predictions[0:5]
# Out:
# array([list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#        list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#        list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#        list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#        list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'])],
#       dtype=object)

# %%
print(len(test_predictions))
print(len(test_labels))
# Out:
# 1057
# 1057

# %% [markdown]
# # Calculate the F1 score for the predicted label.

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score


# Initialize the MultiLabelBinarizer
mlb = MultiLabelBinarizer()

# Fit and transform the actual and predicted labels
actual_binary = mlb.fit_transform(test_labels)
predicted_binary = mlb.transform(test_predictions)

# Calculate the F1 score with 'micro' average for multi-label
f1 = f1_score(actual_binary, predicted_binary, average='micro')

print(f'F1 Score: {f1:.4f}')
# Out:
# F1 Score: 0.8247

# %% [markdown]
# # Get the mapping diseases and treatment mapping
#
# Creates the code or logic to get all the predicted treatments (T) labels corresponding to each disease (D) label in the test dataset **bold text**

# %%
treatment_mapping = {}
diseases_list = set([])

def prepare_disease_and_treatment_mapping(test_features, test_predictions):
  for test_feature, test_prediction in zip(test_features, test_predictions):
    for feature, prediction in zip(test_feature, test_prediction):
      select_all_the_diseases = filter(lambda x: x[1] == 'D', zip(test_feature, test_prediction))
      select_all_the_diseases = map(lambda x: x[0]['text'], select_all_the_diseases)
      diseases = list(select_all_the_diseases)

      if prediction == 'D':
        diseases_list.add(feature['text'])

      if prediction == 'T':
        if feature['text'] == 'radiotherapy':
          print(list(map(lambda x: x['text'], test_feature)))
        treatment_mapping[feature['text']] = diseases

print(treatment_mapping)
# Out:
# {}

# %%
prepare_disease_and_treatment_mapping(test_features, test_predictions)
# Out:
# ['A', '66', '-', 'year', '-', 'old', 'male', 'engineer', 'diagnosed', 'with', 'malignant', 'pleural', 'mesothelioma', '4', 'years', 'previously', 'had', 'thoracotomy', ',', 'radiotherapy', ',', 'and', 'chemotherapy']
# ['purpose', ':', 'many', 'patients', 'with', 'locally', 'advanced', 'non', '-', 'small', '-', 'cell', 'lung', 'cancer', '(', 'la', '-', 'nsclc', ')', 'are', 'eligible', 'for', 'combined', '-', 'modality', 'therapy', '(', 'cmt', ';', 'chemotherapy', 'and', 'radiotherapy', ')']
# ['we', 'aimed', 'to', 'investigate', 'whether', 'biological', 'factors', 'related', 'to', 'radiosensitivity', 'and', 'chemosensitivity', 'have', 'prognostic', 'significance', 'in', 'non', '-', 'small', '-', 'cell', '-', 'lung', '-', 'cancer', '(', 'nsclc', ')', 'patients', 'treated', 'with', 'daily', 'low', 'doses', 'of', 'cisplatin', 'and', 'radiotherapy']
# ['for', 'intrathoracic', 'relapse', 'and', 'severe', 'obstruction', 'of', 'main', 'bronchus', 'and/or', 'superior', 'caval', 'vein', ',', 'radiotherapy', 'is', 'a', 'possibility', 'if', 'not', 'given', 'as', 'part', 'of', 'first', '-', 'line', 'treatment']
# ['amifostine', '(', 'wr-2721', ')', 'is', 'a', 'cytoprotective', 'agent', 'that', 'protects', 'a', 'broad', 'range', 'of', 'normal', 'tissues', 'from', 'the', 'toxic', 'effects', 'of', 'chemotherapy', 'and', 'radiotherapy', 'without', 'attenuating', 'tumour', 'response']

# %%
treatment_mapping
# Out:
# {'methylphenidate': ['attention', 'deficit', 'hyperactivity', 'disorder'],
#  'Antichlamydial': [],
#  'antibiotics': ['symptoms', 'of', 'a', 'common', 'cold'],
#  'electrical': [],
#  'nerve': [],
#  'stimulation': [],
#  '(': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'ENS': [],
#  ')': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'therapy': ['cerebral', 'palsy'],
#  'muscle': [],
#  'EMS': [],
#  'intravenous': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'antibiotic': ['bacterial',
#   'meningitis',
#   'Haemophilus',
#   'influenzae',
#   'meningitis'],
#  'treatment': [],
#  'fenfluramine': ['cardiac', 'disease'],
#  '-': [],
#  'phentermine': ['cardiac', 'disease'],
#  'pylori': [],
#  'intrauterine': ['preeclampsia', '(', 'proteinuric', 'hypertension', ')'],
#  'insemination': ['preeclampsia', '(', 'proteinuric', 'hypertension', ')'],
#  'with': ['chronic', 'hepatitis', 'C'],
#  'donor': ['preeclampsia', '(', 'proteinuric', 'hypertension', ')'],
#  'sperm': [],
#  'versus': ['preeclampsia', '(', 'proteinuric', 'hypertension', ')'],
#  'partner': ['preeclampsia', '(', 'proteinuric', 'hypertension', ')'],
#  'organ': ['cancer'],
#  'transplantation': ['pulmonary', 'hypertension'],
#  'and': [],
#  'chemotherapy': ['resection',
#   'of',
#   'hepatic',
#   'metastases',
#   'from',
#   'colorectal',
#   'cancer'],
#  'thoracotomy': ['malignant', 'pleural', 'mesothelioma'],
#  ',': ['esophageal', 'achalasia'],
#  'radiotherapy': [],
#  'interferon': ['chronic', 'hepatitis', 'C'],
#  'gamma': [],
#  'testicular': [],
#  'retrieval': [],
#  'by': [],
#  'fine': [],
#  'needle': [],
#  'aspiration': [],
#  'TEFNA': [],
#  'open': [],
#  'biopsy': [],
#  'extraction': [],
#  'TESE': [],
#  'bleeding': [],
#  'following': [],
#  'Hepatocerebral': [],
#  'degeneration': [],
#  'portal': [],
#  'systemic': ['malignant', 'pleural', 'effusions', 'from', 'nsclc'],
#  'encephalopathy': [],
#  'Hormone': [],
#  'replacement': [],
#  'tacrolimus': [],
#  'optic': [],
#  'head': [],
#  'Cranial': [],
#  'injuries': [],
#  'combination': ['hepatitis', 'C', 'viremia'],
#  'leucovorin': ['colorectal', 'cancer'],
#  'or': ['pulmonary', 'hypertension'],
#  'cisplatin': ['extensive', 'disease'],
#  'extracorporeal': [],
#  'photopheresis': [],
#  'combined': ['limited', '-', 'stage', 'small', '-', 'cell', 'carcinoma'],
#  'modality': ['limited', '-', 'stage', 'small', '-', 'cell', 'carcinoma'],
#  'cmt': ['locally',
#   'advanced',
#   'non',
#   '-',
#   'small',
#   '-',
#   'cell',
#   'lung',
#   'cancer'],
#  ';': ['locally',
#   'advanced',
#   'non',
#   '-',
#   'small',
#   '-',
#   'cell',
#   'lung',
#   'cancer'],
#  'vip': ['limited', 'stage', 'small', 'cell', 'lung', 'cancer'],
#  'resection': [],
#  'allowing': [],
#  'neoadjuvant': [],
#  'postoperative': ['pathologic',
#   'stage',
#   'i',
#   'non',
#   '-',
#   'small',
#   'cell',
#   'lung',
#   'cancer'],
#  'oral': ['cancer', 'chemotherapy'],
#  'administration': ['pathologic',
#   'stage',
#   'i',
#   'non',
#   '-',
#   'small',
#   'cell',
#   'lung',
#   'cancer'],
#  'lung': ['pulmonary', 'hypertension'],
#  'carcinoma': [],
#  'who': [],
#  'videothoracoscopic': [],
#  'lobectomy': [],
#  'partial': [],
#  'surgical': [],
#  'wbrt': ['carcinoma', 'brain', 'metastasis'],
#  'of': ['resection',
#   'of',
#   'hepatic',
#   'metastases',
#   'from',
#   'colorectal',
#   'cancer'],
#  'ifosfamide': [],
#  'irinotecan': [],
#  'rhg': [],
#  'paclitaxel': [],
#  'carboplatin': ['extensive', 'disease'],
#  'administered': [],
#  'before': [],
#  'surgery': ['spontaneous', 'pneumothorax'],
#  'main': [],
#  'bronchus': [],
#  'and/or': [],
#  'superior': [],
#  'caval': [],
#  'vein': [],
#  'plus': ['chronic', 'hepatitis', 'C'],
#  'pc': [],
#  'vinorelbine': [],
#  'platinum': ['extensive', 'disease'],
#  'dose': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'in': ['extensive', 'disease'],
#  'cancer': [],
#  'amifostine': ['head', 'and', 'neck', 'cancer'],
#  'psoriasis': [],
#  'topical': [],
#  'application': [],
#  'active': [],
#  'vitamin': [],
#  'D3': [],
#  'analogue': [],
#  '1': [],
#  'alpha': ['chronic', 'hepatitis', 'C'],
#  'Guiding': [],
#  'i.m': ['non',
#   '-',
#   'functioning',
#   'endocrine',
#   'pancreatic',
#   'tumor',
#   'with',
#   'progressive',
#   'liver',
#   'and',
#   'lymph',
#   'node',
#   'metastases'],
#  '.': ['non',
#   '-',
#   'functioning',
#   'endocrine',
#   'pancreatic',
#   'tumor',
#   'with',
#   'progressive',
#   'liver',
#   'and',
#   'lymph',
#   'node',
#   'metastases'],
#  'lanreotide': ['non',
#   '-',
#   'functioning',
#   'endocrine',
#   'pancreatic',
#   'tumor',
#   'with',
#   'progressive',
#   'liver',
#   'and',
#   'lymph',
#   'node',
#   'metastases'],
#  'Surgical': ['severe', 'secondary', 'peritonitis'],
#  'management': ['severe', 'secondary', 'peritonitis'],
#  'video': [],
#  'assisted': [],
#  'thoracoscopic': [],
#  'Hib': [],
#  'conjugate': [],
#  'vaccine': [],
#  'Macrolide': ['symptoms', 'of', 'a', 'common', 'cold'],
#  'highly': [],
#  'antiretroviral': [],
#  'inhaled': ['asthma'],
#  'corticosteroids': ['asthma'],
#  'Combination': ['chronic', 'hepatitis', 'C'],
#  'IFN': ['chronic', 'hepatitis', 'C'],
#  'Ribavirin': ['chronic', 'hepatitis', 'C'],
#  'glucocorticoid': [],
#  'pulse': [],
#  'external': [],
#  'beam': [],
#  'radiation': [],
#  'Thrombolytic': ['acute', 'myocardial', 'infarction'],
#  'Aortocoronary': ['ischemic', 'heart', 'disease'],
#  'bypass': ['ischemic', 'heart', 'disease'],
#  'grafting': ['ischemic', 'heart', 'disease'],
#  'Subcutaneous': [],
#  'injection': ['esophageal', 'achalasia'],
#  'irradiated': [],
#  'LLC': [],
#  'conservative': [],
#  'pharmacological': [],
#  'High': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'immunoglobulin': ['multiple', 'sclerosis'],
#  'hdIVIg': ['inflammatory', 'and', 'autoimmune', 'diseases'],
#  'drugs': ['cancer', 'chemotherapy'],
#  'single': [],
#  'agent': [],
#  'botulinum': ['esophageal', 'achalasia'],
#  'toxin': ['esophageal', 'achalasia'],
#  'pneumatic': ['esophageal', 'achalasia'],
#  'dilation': ['esophageal', 'achalasia'],
#  'Tubularized': ['proximal', 'hypospadias'],
#  'incised': ['proximal', 'hypospadias'],
#  'plate': ['proximal', 'hypospadias'],
#  'hypospadias': ['proximal', 'hypospadias'],
#  'Current': [],
#  'Thoracoscopic': ['spontaneous', 'pneumothorax'],
#  'Antiplatelet': ['atrial', 'fibrillation'],
#  'Gene': [],
#  'Percutaneous': [],
#  'transluminal': [],
#  'angioplasty': [],
#  'Single': ['pulmonary', 'hypertension'],
#  'double': ['pulmonary', 'hypertension'],
#  'Interferon': ['multiple', 'sclerosis'],
#  'beta': ['multiple', 'sclerosis'],
#  'Intravenous': ['multiple', 'sclerosis'],
#  'Hyperbaric': ['cerebral', 'palsy'],
#  'oxygen': ['cerebral', 'palsy'],
#  'Matrix': ['cancer'],
#  'metalloproteinase': ['cancer'],
#  'inhibitors': ['cancer'],
#  'bite': [],
#  'Hepatic': ['resection',
#   'of',
#   'hepatic',
#   'metastases',
#   'from',
#   'colorectal',
#   'cancer'],
#  'arterial': ['resection',
#   'of',
#   'hepatic',
#   'metastases',
#   'from',
#   'colorectal',
#   'cancer'],
#  'infusion': ['resection',
#   'of',
#   'hepatic',
#   'metastases',
#   'from',
#   'colorectal',
#   'cancer']}

# %%
diseases_list
# Out:
# {"'s",
#  '(',
#  ')',
#  ',',
#  '-',
#  '3',
#  'A2',
#  'AIDS',
#  'Acute',
#  'Alzheimer',
#  'Blastocystis',
#  'C',
#  'Cancer',
#  'Chlamydia',
#  'Contemporary',
#  'Crohn',
#  'Cushing',
#  'Darier',
#  'Eisenmenger',
#  'Gorlin',
#  'Gynaecological',
#  'HIV',
#  'Haemophilus',
#  'IIB',
#  'IVB',
#  'Interferon',
#  'Intramedullary',
#  'Johne',
#  'Kaposi',
#  'Metastatic',
#  'Myoepithelial',
#  'Ovarian',
#  'Ovine',
#  'PPH',
#  'Parkinson',
#  'Pendred',
#  'Progressive',
#  'Q',
#  'RSV',
#  'Spontaneous',
#  'TNM',
#  'a',
#  'abdominal',
#  'accompanying',
#  'achalasia',
#  'acute',
#  'adenocarcinoma',
#  'administration',
#  'adrenal',
#  'adrenocorticotropic',
#  'advanced',
#  'against',
#  'amyloid',
#  'and',
#  'anemia',
#  'angina',
#  'anomalies',
#  'anterior',
#  'aplasia',
#  'arthritis',
#  'as',
#  'associated',
#  'asthma',
#  'atrial',
#  'attention',
#  'attributable',
#  'autoimmune',
#  'autologous',
#  'bacterial',
#  'bilateral',
#  'biliary',
#  'bladder',
#  'bowel',
#  'brain',
#  'breast',
#  'bronchial',
#  'bronchiolitis',
#  'bronchogenic',
#  'cancer',
#  'carbon',
#  'carcinoma',
#  'cardiac',
#  'cell',
#  'cerebral',
#  'cervical',
#  'chemotherapy',
#  'childhood',
#  'cholestasis',
#  'chronic',
#  'cold',
#  'colic',
#  'colonic',
#  'colony',
#  'colorectal',
#  'combined',
#  'common',
#  'complicating',
#  'conditions',
#  'confirmed',
#  'congenital',
#  'congestive',
#  'control',
#  'coronary',
#  'cortical',
#  'deficit',
#  'dependent',
#  'depressed',
#  'derived',
#  'diabetes',
#  'diabetic',
#  'disease',
#  'diseases',
#  'disorder',
#  'disseminated',
#  'distress',
#  'diverticular',
#  'duodenal',
#  'dysfunction',
#  'dyskinesia',
#  'early',
#  'effusions',
#  'end',
#  'endocrine',
#  'epithelial',
#  'erythematosus',
#  'esophageal',
#  'exceptionalism',
#  'extensive',
#  'failure',
#  'female',
#  'fenfluramine',
#  'fibrillation',
#  'following',
#  'foot',
#  'from',
#  'functioning',
#  'fungal',
#  'fungoides',
#  'gangliosides',
#  'gene',
#  'gestational',
#  'grade',
#  'granulocyte',
#  'gunshot',
#  'head',
#  'hearing',
#  'heart',
#  'heat',
#  'hemolytic',
#  'hemorrhage',
#  'hemorrhagic',
#  'heparin',
#  'hepatic',
#  'hepatitis',
#  'hereditary',
#  'herpesvirus',
#  'hodgkin',
#  'hominis',
#  'hormone',
#  'hydrocephalus',
#  'hyperactivity',
#  'hyperplasia',
#  'hypertension',
#  'hypospadias',
#  'i',
#  'immunodeficiency',
#  'in',
#  'incontinence',
#  'increase',
#  'indication',
#  'inducible',
#  'infarction',
#  'infection',
#  'infections',
#  'infestation',
#  'inflammatory',
#  'influenza',
#  'influenzae',
#  'injuries',
#  'insufficiency',
#  'insulin',
#  'intra',
#  'irritable',
#  'ischemia',
#  'ischemic',
#  'large',
#  'left',
#  'lesions',
#  'leukaemia',
#  'leukaemias',
#  'lice',
#  'limited',
#  'liver',
#  'load',
#  'locally',
#  'loss',
#  'louse',
#  'low',
#  'lung',
#  'lupus',
#  'lymph',
#  'lymphoblastic',
#  'lymphoma',
#  'lymphomas',
#  'malaria',
#  'malignant',
#  'manageable',
#  'melanoma',
#  'mellitus',
#  'meningitis',
#  'mesothelioma',
#  'metastases',
#  'metastasis',
#  'metastatic',
#  'migraine',
#  'mild',
#  'moderate',
#  'monoxide',
#  'multiple',
#  'murine',
#  'mycosis',
#  'myeloma',
#  'myocardial',
#  'myofascial',
#  'neck',
#  'nitric',
#  'node',
#  'non',
#  'noncirrhotic',
#  'nsclc',
#  'obstructive',
#  'odontogenic',
#  'of',
#  'open',
#  'or',
#  'oral',
#  'ovarian',
#  'oxide',
#  'pain',
#  'palsy',
#  'pancreatic',
#  'partial',
#  'pathologic',
#  'patients',
#  'peritonitis',
#  'persistent',
#  'pertussis',
#  'physiology',
#  'piglet',
#  'pleural',
#  'pleuritic',
#  'pneumothorax',
#  'point',
#  'poisoning',
#  'polyps',
#  'portal',
#  'postoperative',
#  'postvitrectomy',
#  'predominance',
#  'preeclampsia',
#  'presenting',
#  'primary',
#  'progressive',
#  'prostate',
#  'protection',
#  'proteinuric',
#  'proximal',
#  'pseudo',
#  'psoriasis',
#  'pulmonary',
#  'reabsorption',
#  'reattendance',
#  'rectal',
#  'recurrent',
#  'refractory',
#  'relief',
#  'renal',
#  'repetitive',
#  'resection',
#  'respiratory',
#  'responsive',
#  'rheumatic',
#  'rheumatoid',
#  'rupture',
#  'sarcoma',
#  'sarcomas',
#  'schizophrenia',
#  'sclc',
#  'sclerosis',
#  'secondary',
#  'seizures',
#  'sensorineural',
#  'severe',
#  'severely',
#  'shock',
#  'skin',
#  'small',
#  'sodium',
#  'soft',
#  'sore',
#  'splenic',
#  'spontaneous',
#  'stable',
#  'stage',
#  'stenoses',
#  'stone',
#  'stones',
#  'strain',
#  'stress',
#  'such',
#  'supraclavicular',
#  'surgery',
#  'surgical',
#  'symptoms',
#  'syndrome',
#  'synthase',
#  'systemic',
#  'tangential',
#  'therapy',
#  'throat',
#  'tissue',
#  'to',
#  'toxicities',
#  'tracheobronchial',
#  'trachomatis',
#  'treat',
#  'treatment',
#  'trigger',
#  'tubule',
#  'tumor',
#  'tumors',
#  'ulcer',
#  'undergoing',
#  'unstable',
#  'untreated',
#  'upper',
#  'urinary',
#  'vaccines',
#  'ventricular',
#  'viral',
#  'viremia',
#  'virus',
#  'vitreous',
#  'wall',
#  'wave',
#  'with',
#  'wounds'}

# %% [markdown]
# # Predicts the treatment for the disease named 'hereditary retinoblastoma'

# %%
## disease not found in the list, my bad.
